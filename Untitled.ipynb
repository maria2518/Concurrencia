# %% [markdown]
# María Teresa Rodríguez Gómez, exp 22072362

# %%
Url de la practica:

# %% [markdown]
# # First prg.

# %% [markdown]
# ## Cree un prg que calcule la sec de fib de 30, 40, 80

# %% [markdown]
# ### La formula que he usado es :

# %%
from IPython import display

# %%
display.Image("Primer programa/Captura de pantalla 2021-09-16 182214.png")

# %%
def fib(n):
    if n<=1:
        return n
    else:
        return (fib(n-1) + fib(n-2))

# %%
fib(40)
# Out:
# 102334155

# %%
pwd
# Out:
# 'C:\\Users\\mtrgo\\Primerprograma'

# %%
ls
# Out:
#  El volumen de la unidad C es Windows
#  El número de serie del volumen es: 6A83-EEB6
#
#  Directorio de C:\Users\mtrgo\Primerprograma
#
# 16/09/2021  19:08    <DIR>          .
# 16/09/2021  19:08    <DIR>          ..
# 16/09/2021  18:29    <DIR>          .ipynb_checkpoints
# 16/09/2021  18:26           105.775 Captura de pantalla 2021-09-16 182214.png
# 16/09/2021  19:08           145.072 Untitled.ipynb
#                2 archivos        250.847 bytes
#                3 dirs  238.574.342.144 bytes libres

# %%
git remote add origin https://github.com/maria2518/primer_programa_fib.git
# Out:
#   File "<ipython-input-3-98dcd9a716cc>", line 1
#     git remote add origin https://github.com/maria2518/primer_programa_fib.git
#         ^
# SyntaxError: invalid syntax
